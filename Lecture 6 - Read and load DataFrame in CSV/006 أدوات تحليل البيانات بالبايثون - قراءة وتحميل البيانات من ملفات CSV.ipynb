# %%
import pandas as pd

# %%
type(pd.read_csv('insurance.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv(filepath_or_buffer = 'insurance.csv', header = 0).head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
pd.read_csv(filepath_or_buffer = 'insurance.csv', header = 0).tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
pd.read_csv(filepath_or_buffer = 'insurance.csv', usecols  = ["region", "sex", "age"]).head()
# Out:
#    age     sex     region
# 0   19  female  southwest
# 1   18    male  southeast
# 2   28    male  southeast
# 3   33    male  northwest
# 4   32    male  northwest

# %%
pd.read_csv('Advertising.csv', index_col = "Unnamed: 0").head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
pd.read_csv('Advertising.csv', index_col = "TV")

# %%
pd.read_csv('friends.csv', sep = "|")
# Out:
#       fname        lname age_sex section height(cm) weight(kg)  age  spend_A  \
# 0     Rahul       Pandey    37_M       B      175.4       85.6   37   1500.0
# 1    Rakesh        Kumar    38_M       B        NaN         xx   38      NaN
# 2    Nitesh       Mondol    35_F       B      165.1          ?   35    500.0
# 3    Arvind      Dwivedi    40_M       A          0       55.6   40    300.0
# 4    Nikhil   Shikharwar    39_M       B      160.8        160   39    200.0
# 5  Ashutosh    Merothiya    36_M       A         xx        -60   36    100.0
# 6   Shubhro          Das    35_F       C      170.3       75.5   35      NaN
# 7   Suvendu          Das    34_M       C      155.1       56.8   34   1000.0
# 8   Swadesh        Kumar    36_M       C      154.2       60.6   36    100.0
# 9      Arun  Vishwakarma    38_F       A      162.1       58.7   38    600.0
#
#    spend_B spend_C
# 0    200.0     300
# 1   1000.0     NaN
# 2   -100.0     200
# 3    300.0     NaN
# 4      NaN     300
# ...

# %%
pd.read_csv('friends.csv', delimiter = "|")
# Out:
#       fname        lname age_sex section height(cm) weight(kg)  age  spend_A  \
# 0     Rahul       Pandey    37_M       B      175.4       85.6   37   1500.0
# 1    Rakesh        Kumar    38_M       B        NaN         xx   38      NaN
# 2    Nitesh       Mondol    35_F       B      165.1          ?   35    500.0
# 3    Arvind      Dwivedi    40_M       A          0       55.6   40    300.0
# 4    Nikhil   Shikharwar    39_M       B      160.8        160   39    200.0
# 5  Ashutosh    Merothiya    36_M       A         xx        -60   36    100.0
# 6   Shubhro          Das    35_F       C      170.3       75.5   35      NaN
# 7   Suvendu          Das    34_M       C      155.1       56.8   34   1000.0
# 8   Swadesh        Kumar    36_M       C      154.2       60.6   36    100.0
# 9      Arun  Vishwakarma    38_F       A      162.1       58.7   38    600.0
#
#    spend_B spend_C
# 0    200.0     300
# 1   1000.0     NaN
# 2   -100.0     200
# 3    300.0     NaN
# 4      NaN     300
# ...

# %%
pd.read_csv('wiki4HE.csv', sep = ";")
pd.read_csv('wiki4HE.csv', delimiter = ";").head()
# Out:
#    AGE  GENDER DOMAIN  PhD YEARSEXP  UNIVERSITY UOC_POSITION OTHER_POSITION  \
# 0   40       0      2    1       14           1            2              ?
# 1   42       0      5    1       18           1            2              ?
# 2   37       0      4    1       13           1            3              ?
# 3   40       0      4    0       13           1            3              ?
# 4   51       0      6    0        8           1            3              ?
#
#   OTHERSTATUS USERWIKI  ... BI2 Inc1 Inc2 Inc3 Inc4 Exp1 Exp2 Exp3 Exp4 Exp5
# 0           ?        0  ...   3    5    5    5    5    4    4    4    1    2
# 1           ?        0  ...   2    4    4    3    4    2    2    4    2    4
# 2           ?        0  ...   1    5    3    5    5    2    2    2    1    3
# 3           ?        0  ...   3    3    4    4    3    4    4    3    3    4
# 4           ?        1  ...   5    5    5    4    4    5    5    5    4    4
#
# [5 rows x 53 columns]

# %%
df = pd.read_csv('weather.csv')

# %%
df[df.duplicated() == True]
# Out:
#     applicable_date  the_temp          wind_speed  humidity  air_pressure  \
# 13  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 20  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 27  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 34  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 41  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 48  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 55  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 62  applicable_date  the_temp          wind_speed  humidity  air_pressure
# 68       2021-10-28     28.73  6.3688757655293085        49        1016.0
#
#            visibility
# 13         visibility
# 20         visibility
# 27         visibility
# 34         visibility
# 41         visibility
# 48         visibility
# 55         visibility
# 62         visibility
# ...

# %%
df.duplicated() .value_counts()
# Out:
# False    60
# True      9
# dtype: int64

# %%
df.drop(df[df.duplicated() == True].index, axis=0, inplace = True)

# %%
df.duplicated() .value_counts()
# Out:
# False    60
# dtype: int64

# %%
pd.read_csv('wiki4HE.csv', sep = ";", nrows = None, encoding = "utf-8").replace("?", 10)
# Out:
#      AGE  GENDER DOMAIN  PhD YEARSEXP  UNIVERSITY UOC_POSITION OTHER_POSITION  \
# 0     40       0      2    1       14           1            2             10
# 1     42       0      5    1       18           1            2             10
# 2     37       0      4    1       13           1            3             10
# 3     40       0      4    0       13           1            3             10
# 4     51       0      6    0        8           1            3             10
# ..   ...     ...    ...  ...      ...         ...          ...            ...
# 908   43       0      5    1       21           2           10             10
# 909   53       0      6    0       25           2           10             10
# 910   39       0      5    1        9           2           10             10
# 911   40       0      3    1       10           2           10             10
# 912   41       1      3    1       12           2           10             10
#
# ...

# %%
pd.read_csv('HDI.csv', encoding = "latin-1")
# Out:
#     Coverage  HDI Rank                                            Country  \
# 0    Country     169.0                                        Afghanistan
# 1    Country      69.0                                            Albania
# 2    Country      91.0                                            Algeria
# 3    Country      36.0                                            Andorra
# 4    Country     148.0                                             Angola
# ..       ...       ...                                                ...
# 199  Regions       NaN                                 Sub-Saharan Africa
# 200  Regions       NaN                          Least Developed Countries
# 201  Regions       NaN                     Small Island Developing States
# 202  Regions       NaN  Organization for Economic Co-operation and Dev...
# 203  Regions       NaN                                              World
#
#       1990   1991   1992   1993   1994   1995   1996  ...   2010   2011  \
# ...
