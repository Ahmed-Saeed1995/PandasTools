# %%
import pandas as pd
import sqlite3

# %%
db = sqlite3.connect('library.db')

SQLScript = "SELECT * from books"

# %%
pd.read_sql_query(SQLScript, db, index_col = "book_id")

# %%
db = sqlite3.connect('chinook.db')

SQLScript = "SELECT * from invoices"

df = pd.read_sql_query(SQLScript, db, index_col = "InvoiceId")

# %%
db = sqlite3.connect('sakila.db')

SQLScript = "SELECT * from customer_list"

pd.read_sql_query(SQLScript, db, index_col = "ID")
# Out:
#                    name                   address zip_code phone  \
# ID
# 1            MARY SMITH            1913 Hanoi Way    35200
# 2      PATRICIA JOHNSON          1121 Loja Avenue    17886
# 3        LINDA WILLIAMS         692 Joliet Street    83579
# 4         BARBARA JONES          1566 Inegl Manor    53561
# 5       ELIZABETH BROWN           53 Idfu Parkway    42399
# ..                  ...                       ...      ...   ...
# 595  TERRENCE GUNDERSON       844 Bucuresti Place    36603
# 596    ENRIQUE FORSYTHE  1101 Bucuresti Boulevard    97661
# 597      FREDDIE DUGGAN    1103 Quilmes Boulevard    52137
# 598       WADE DELVALLE       1331 Usak Boulevard    61960
# 599      AUSTIN CINTRON      1325 Fukuyama Street    27107
#
#                city        country   notes  SID
# ID
# 1            Sasebo          Japan  active    1
# 2    San Bernardino  United States  active    1
# 3           Athenai         Greece  active    1
# ...

# %%
type(pd.read_sql_query(SQLScript, db, index_col = "ID"))
# Out:
# pandas.core.frame.DataFrame
